# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from sklearn.neighbors import NearestNeighbors 
from sklearn import datasets, neighbors
from scipy import linalg
import warnings
warnings.filterwarnings('ignore')

# %%
from keras.datasets import reuters
import numpy as np
# save np.load
np_load_old = np.load

# modify the default parameters of np.load
np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)

# call load_data with allow_pickle implicitly set to true
(x_train, y_train), (x_test, y_test) = reuters.load_data(path="reuters.npz",
                                                         num_words=None,
                                                         skip_top=0,
                                                         maxlen=None,
                                                         test_split=0.2,
                                                         seed=113,
                                                         start_char=1,
                                                         oov_char=2,
                                                         index_from=3)
# restore np.load for future normal usage
np.load = np_load_old

# %%
mnist = input_data.read_data_sets("MNIST_data/")
# Out:
# WARNING:tensorflow:From <ipython-input-2-7d08ec3dfcb7>:1: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /opt/anaconda3/envs/ML/lib/python3.7/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /opt/anaconda3/envs/ML/lib/python3.7/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /opt/anaconda3/envs/ML/lib/python3.7/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /opt/anaconda3/envs/ML/lib/python3.7/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
X_m = mnist.train.images
y = mnist.train.labels

# %% [markdown]
# # AutoEncoding LLE

# %% [markdown]
# ## LLE
#
# First we define the LLE class to be used in the next step

# %%
class LLE:
    def __init__(self,X,K):
        self.K = K
        self.X = X
        
    def Knbor_Mat(self,dist_metric = "euclidean", algorithm = "ball_tree"):
        
        
        K = self.K
        X = self.X
        
        knn = neighbors.NearestNeighbors(K+1, metric = dist_metric, algorithm=algorithm).fit(X)
        distances, nbors = knn.kneighbors(X)
        return(nbors[:,1:])
    def get_weights(self,reg):
        
        K = self.K
        X = self.X
        
        nbors = self.Knbor_Mat()
        n,_ = self.X.shape
        Weights = np.zeros((n,n))
        for i in range(n):

            X_bors = X[nbors[i],:] - X[i]
            cov_nbors = np.dot(X_bors, X_bors.T)
            #regularization tems
            trace = np.trace(cov_nbors)
            if trace >0 :
                R = reg*trace
            else:
                R = reg
            cov_nbors.flat[::K+1] += R
            weights = linalg.solve(cov_nbors, np.ones(K).T, sym_pos=True)
            weights = weights/weights.sum()
            Weights[i, nbors[i]] = weights

        return(Weights)

# %% [markdown]
# ## DAE

# %% [markdown]
# ### Initialisation Of the hyper params
#
#
# In order to implement our algorithm combining DAE and LLE we will first initialize the hyper params

# %%
Learning_rate = 0.001
Lr_Epochs = 200
BATCH_SIZE = 256
NUM_BATCHES = int(mnist.train.num_examples/BATCH_SIZE)


Hidden_size_1 = 256
Hidden_size_2 = 128
Input_size = 784

Lambda_reg_rate = 0.01

Print_freq = 1
display = 10

# %% [markdown]
# ### Conception of the DAE Architecture
#
# Now we can build the deep autoencoding architecture
#
# We will have in this arcitecture a 4 layers Neural network including 2 encoding layer (Encoder) and 2 decoding layers (Decoder)

# %%
X = tf.placeholder("float", [None, Input_size])

# %% [markdown]
# #### LLE S Matrice Holder
#
# we will include LLE to our learning step and in order to do so we create a placeholder for the S matrice

# %%
S = tf.placeholder(tf.float32,[None, None])

# %% [markdown]
# #### Weights Matrices

# %%
Hidden_weights = {
'encodeur_h1': tf.Variable(tf.random_normal([Input_size, Hidden_size_1])),
'encodeur_h2': tf.Variable(tf.random_normal([Hidden_size_1, Hidden_size_2])),
'decodeur_h1': tf.Variable(tf.random_normal([Hidden_size_2, Hidden_size_1])),
'decodeur_h2': tf.Variable(tf.random_normal([Hidden_size_1, Input_size])),
}

# %% [markdown]
# #### Biais Matrices

# %%
biais = {
'encodeur_b1': tf.Variable(tf.random_normal([Hidden_size_1])),
'encodeur_b2': tf.Variable(tf.random_normal([Hidden_size_2])),
'decodeur_b1': tf.Variable(tf.random_normal([Hidden_size_1])),
'decodeur_b2': tf.Variable(tf.random_normal([Input_size])),
}

# %% [markdown]
# #### First layer encodeur_in = (W*x + b)

# %%
encodeur_in = tf.nn.sigmoid(tf.add(tf.matmul(X,Hidden_weights['encodeur_h1']),biais['encodeur_b1']))

# %% [markdown]
# #### Second layer encodeur_out = (W * encodeur_in + b)

# %%
encodeur_out = tf.nn.sigmoid(tf.add(tf.matmul(encodeur_in,Hidden_weights['encodeur_h2']),biais['encodeur_b2']))

# %% [markdown]
# #### First decoding layer decodeur_in = (W*encodeur_out + b)

# %%
decodeur_in = tf.nn.sigmoid(tf.add(tf.matmul(encodeur_out,Hidden_weights['decodeur_h1']),biais['decodeur_b1']))

# %% [markdown]
# #### Second decoding layer decodeur_out = (W*decodeur_in + b)

# %%
decodeur_out = tf.nn.sigmoid(tf.add (tf.matmul(decodeur_in,Hidden_weights['decodeur_h2']),biais['decodeur_b2']))

# %%
X_reconst = decodeur_out
X_originale = X

# %% [markdown]
# ### Loss Function
# Now we define the loss function to be optimized
#
# #### Learning loss function
#
#
# $$
# \min _{\theta_{1}, \theta_{2}, \mathbf{S}}\left\|\mathbf{X}-g_{\theta_{2}}\left(f_{\theta_{1}}(\mathbf{X})\right)\right\|^{2}+\lambda\left\|f_{\theta_{1}}(\mathbf{X})-\mathbf{S} f_{\theta_{1}}(\mathbf{X})\right\|^{2}$$

# %%
Train_loss_func = tf.reduce_mean(tf.pow(X_originale - X_reconst, 2)) + Lambda_reg_rate * tf.reduce_mean(tf.pow(encodeur_out - tf.matmul(S,encodeur_out), 2))

# %% [markdown]
# #### Test Loss function

# %% [markdown]
# $$
# \left\|\mathbf{X}-g_{\theta_{2}}\left(f_{\theta_{1}}(\mathbf{X})\right)\right\|^{2}$$

# %%
Test_loss_func = tf.reduce_mean(tf.pow(X_originale- X_reconst, 2))

# %% [markdown]
# #### Optimizer ( RMSProp )

# %%
optimisation = tf.train.RMSPropOptimizer(Learning_rate).minimize(Train_loss_func)

# %% [markdown]
# ### Learning step

# %%
initialisation = tf.global_variables_initializer()
Learning_losses, Test_losses = [],  []
Iter_weights = []

# %%
with tf.Session() as sess:
    sess.run(initialisation)
    NUM_BATCHES = int(mnist.train.num_examples/BATCH_SIZE)
    for Epoch in range(Lr_Epochs):
        for i in range(NUM_BATCHES):
            
            
            batch_xs, _ = mnist.train.next_batch(BATCH_SIZE)
            sortie = sess.run(encodeur_out, feed_dict={X: batch_xs})
            
            
            lle = LLE(sortie,10)
            
            W = lle.get_weights(0.01)
            
            
            
            _, tr_loss = sess.run([optimisation, Train_loss_func],feed_dict={X: batch_xs, S: W})
            
            batch_x_test_s, _ = mnist.test.next_batch(BATCH_SIZE)
            #X_reconst = sess.run(X_reconst, feed_dict={X: mnist.test.images[:BATCH_SIZE]})
            
            tst_loss = sess.run([Test_loss_func],feed_dict={X_originale: batch_x_test_s})[0]
            

            
            
            
        if Epoch % Print_freq == 0:
            Learning_losses.append(tr_loss)
            Test_losses.append(tst_loss)
            Iter_weights.append(W)


            print("Epoch:", '%04d' % (Epoch+1),
                      "Train Loss=", "{:.9f}".format(tr_loss), "Test loss=", "{:.9f}".format(tst_loss))

    print("Done!")
    encode_out = sess.run(encodeur_out, feed_dict={X:X_m})
    encode_decode = sess.run(X_reconst, feed_dict={X: mnist.test.images[:]})
    encode_decode_total = sess.run(X_reconst, feed_dict={X: mnist.test.images[:]})
# Out:
# Epoch: 0001 Train Loss= 0.198904380 Test loss= 0.197289795
# Epoch: 0002 Train Loss= 0.171532005 Test loss= 0.169481382
# Epoch: 0003 Train Loss= 0.159137219 Test loss= 0.159385592
# Epoch: 0004 Train Loss= 0.151298270 Test loss= 0.149296999
# Epoch: 0005 Train Loss= 0.144199625 Test loss= 0.142341182
# Epoch: 0006 Train Loss= 0.132005543 Test loss= 0.131266221
# Epoch: 0007 Train Loss= 0.124717593 Test loss= 0.126615539
# Epoch: 0008 Train Loss= 0.122808196 Test loss= 0.122369446
# Epoch: 0009 Train Loss= 0.117425837 Test loss= 0.116822146
# Epoch: 0010 Train Loss= 0.113113105 Test loss= 0.113382503
# Epoch: 0011 Train Loss= 0.110903278 Test loss= 0.111410543
# Epoch: 0012 Train Loss= 0.108704932 Test loss= 0.109025314
# Epoch: 0013 Train Loss= 0.106157720 Test loss= 0.105946884
# Epoch: 0014 Train Loss= 0.103923671 Test loss= 0.105664194
# Epoch: 0015 Train Loss= 0.102896318 Test loss= 0.102438949
# Epoch: 0016 Train Loss= 0.102670543 Test loss= 0.100520581
# Epoch: 0017 Train Loss= 0.101311333 Test loss= 0.103502169
# Epoch: 0018 Train Loss= 0.099256553 Test loss= 0.100531399
# Epoch: 0019 Train Loss= 0.101747207 Test loss= 0.099172711
# Epoch: 0020 Train Loss= 0.099248536 Test loss= 0.097955741
# Epoch: 0021 Train Loss= 0.099547088 Test loss= 0.098284431
# Epoch: 0022 Train Loss= 0.096213281 Test loss= 0.095795132
# Epoch: 0023 Train Loss= 0.095827833 Test loss= 0.095107436
# Epoch: 0024 Train Loss= 0.092481568 Test loss= 0.093266584
# Epoch: 0025 Train Loss= 0.095705897 Test loss= 0.094784871
# Epoch: 0026 Train Loss= 0.093061432 Test loss= 0.093534760
# Epoch: 0027 Train Loss= 0.093259066 Test loss= 0.093552530
# Epoch: 0028 Train Loss= 0.095046304 Test loss= 0.096035808
# Epoch: 0029 Train Loss= 0.092527062 Test loss= 0.092249930
# Epoch: 0030 Train Loss= 0.091324635 Test loss= 0.090410590
# Epoch: 0031 Train Loss= 0.092338853 Test loss= 0.090804569
# Epoch: 0032 Train Loss= 0.089822985 Test loss= 0.088838264
# Epoch: 0033 Train Loss= 0.088419102 Test loss= 0.088468686
# Epoch: 0034 Train Loss= 0.088756286 Test loss= 0.089795485
# Epoch: 0035 Train Loss= 0.085426405 Test loss= 0.086904489
# Epoch: 0036 Train Loss= 0.087893561 Test loss= 0.087987684
# Epoch: 0037 Train Loss= 0.087444007 Test loss= 0.089188740
# Epoch: 0038 Train Loss= 0.086343572 Test loss= 0.087575406
# Epoch: 0039 Train Loss= 0.086605221 Test loss= 0.086982347
# Epoch: 0040 Train Loss= 0.087813281 Test loss= 0.087422371
# Epoch: 0041 Train Loss= 0.085823350 Test loss= 0.087786108
# Epoch: 0042 Train Loss= 0.083697535 Test loss= 0.084754124
# Epoch: 0043 Train Loss= 0.085609682 Test loss= 0.084378220
# Epoch: 0044 Train Loss= 0.086033396 Test loss= 0.085591123
# Epoch: 0045 Train Loss= 0.082631007 Test loss= 0.080834664
# Epoch: 0046 Train Loss= 0.082395121 Test loss= 0.082393557
# Epoch: 0047 Train Loss= 0.082210571 Test loss= 0.082565919
# Epoch: 0048 Train Loss= 0.080863275 Test loss= 0.080774374
# Epoch: 0049 Train Loss= 0.081823580 Test loss= 0.082211345
# Epoch: 0050 Train Loss= 0.081206128 Test loss= 0.082810409
# Epoch: 0051 Train Loss= 0.081185535 Test loss= 0.081608064
# Epoch: 0052 Train Loss= 0.080619745 Test loss= 0.080440737
# Epoch: 0053 Train Loss= 0.079008952 Test loss= 0.078724675
# Epoch: 0054 Train Loss= 0.079058148 Test loss= 0.080594152
# Epoch: 0055 Train Loss= 0.077443771 Test loss= 0.077934705
# Epoch: 0056 Train Loss= 0.077613510 Test loss= 0.078453258
# Epoch: 0057 Train Loss= 0.076772176 Test loss= 0.078040063
# Epoch: 0058 Train Loss= 0.075582698 Test loss= 0.079111278
# Epoch: 0059 Train Loss= 0.073988840 Test loss= 0.074132010
# Epoch: 0060 Train Loss= 0.074482895 Test loss= 0.072827458
# Epoch: 0061 Train Loss= 0.074339829 Test loss= 0.074619591
# Epoch: 0062 Train Loss= 0.074500464 Test loss= 0.074342467
# Epoch: 0063 Train Loss= 0.074997827 Test loss= 0.075548343
# Epoch: 0064 Train Loss= 0.072354764 Test loss= 0.072740212
# Epoch: 0065 Train Loss= 0.074222863 Test loss= 0.072483338
# Epoch: 0066 Train Loss= 0.072005786 Test loss= 0.072499081
# Epoch: 0067 Train Loss= 0.073928513 Test loss= 0.074862383
# Epoch: 0068 Train Loss= 0.072872303 Test loss= 0.073371463
# Epoch: 0069 Train Loss= 0.076227970 Test loss= 0.076600112
# Epoch: 0070 Train Loss= 0.072502747 Test loss= 0.072032526
# Epoch: 0071 Train Loss= 0.071658149 Test loss= 0.072616965
# Epoch: 0072 Train Loss= 0.071757592 Test loss= 0.073240720
# Epoch: 0073 Train Loss= 0.071821399 Test loss= 0.071489036
# Epoch: 0074 Train Loss= 0.071824990 Test loss= 0.072357409
# Epoch: 0075 Train Loss= 0.071345083 Test loss= 0.071929105
# Epoch: 0076 Train Loss= 0.070622936 Test loss= 0.072429158
# Epoch: 0077 Train Loss= 0.069802791 Test loss= 0.070208356
# Epoch: 0078 Train Loss= 0.070342451 Test loss= 0.068703294
# Epoch: 0079 Train Loss= 0.068455592 Test loss= 0.070781179
# Epoch: 0080 Train Loss= 0.068219788 Test loss= 0.070527226
# Epoch: 0081 Train Loss= 0.068923824 Test loss= 0.068416372
# Epoch: 0082 Train Loss= 0.069063790 Test loss= 0.068411879
# Epoch: 0083 Train Loss= 0.067362450 Test loss= 0.067594104
# Epoch: 0084 Train Loss= 0.067288265 Test loss= 0.066847444
# Epoch: 0085 Train Loss= 0.068751067 Test loss= 0.067985334
# Epoch: 0086 Train Loss= 0.067754030 Test loss= 0.068482511
# Epoch: 0087 Train Loss= 0.067240536 Test loss= 0.066177972
# Epoch: 0088 Train Loss= 0.065400764 Test loss= 0.066659346
# Epoch: 0089 Train Loss= 0.066968605 Test loss= 0.064588733
# Epoch: 0090 Train Loss= 0.063819796 Test loss= 0.064014010
# Epoch: 0091 Train Loss= 0.065588512 Test loss= 0.064338341
# Epoch: 0092 Train Loss= 0.064315915 Test loss= 0.062928714
# Epoch: 0093 Train Loss= 0.062203750 Test loss= 0.062783740
# Epoch: 0094 Train Loss= 0.065767571 Test loss= 0.065634497
# Epoch: 0095 Train Loss= 0.063034244 Test loss= 0.063318104
# Epoch: 0096 Train Loss= 0.064958006 Test loss= 0.064506344
# Epoch: 0097 Train Loss= 0.061917040 Test loss= 0.062502518
# Epoch: 0098 Train Loss= 0.061137542 Test loss= 0.061782476
# Epoch: 0099 Train Loss= 0.060935333 Test loss= 0.060608361
# Epoch: 0100 Train Loss= 0.060952585 Test loss= 0.060012400
# Epoch: 0101 Train Loss= 0.059147906 Test loss= 0.060986008
# Epoch: 0102 Train Loss= 0.060541626 Test loss= 0.061654795
# Epoch: 0103 Train Loss= 0.059130710 Test loss= 0.060160082
# Epoch: 0104 Train Loss= 0.059959114 Test loss= 0.059796344
# Epoch: 0105 Train Loss= 0.060785018 Test loss= 0.059956852
# Epoch: 0106 Train Loss= 0.059746221 Test loss= 0.059314184
# Epoch: 0107 Train Loss= 0.059062175 Test loss= 0.059453838
# Epoch: 0108 Train Loss= 0.060215455 Test loss= 0.060132470
# Epoch: 0109 Train Loss= 0.059502181 Test loss= 0.060990918
# Epoch: 0110 Train Loss= 0.059948537 Test loss= 0.058831185
# Epoch: 0111 Train Loss= 0.059448712 Test loss= 0.060694136
# Epoch: 0112 Train Loss= 0.058970477 Test loss= 0.060031001
# Epoch: 0113 Train Loss= 0.060064182 Test loss= 0.059485368
# Epoch: 0114 Train Loss= 0.058014300 Test loss= 0.059495606
# Epoch: 0115 Train Loss= 0.057964049 Test loss= 0.058528714
# Epoch: 0116 Train Loss= 0.058103133 Test loss= 0.058703609
# Epoch: 0117 Train Loss= 0.056797553 Test loss= 0.056610733
# Epoch: 0118 Train Loss= 0.057966642 Test loss= 0.058586385
# Epoch: 0119 Train Loss= 0.058427673 Test loss= 0.059711605
# Epoch: 0120 Train Loss= 0.059303734 Test loss= 0.057503067
# Epoch: 0121 Train Loss= 0.055296697 Test loss= 0.056118287
# Epoch: 0122 Train Loss= 0.055939853 Test loss= 0.056041308
# Epoch: 0123 Train Loss= 0.058437090 Test loss= 0.057393968
# Epoch: 0124 Train Loss= 0.055614118 Test loss= 0.056204394
# Epoch: 0125 Train Loss= 0.056585707 Test loss= 0.055795733
# Epoch: 0126 Train Loss= 0.056972411 Test loss= 0.058118045
# Epoch: 0127 Train Loss= 0.054059029 Test loss= 0.054849762
# Epoch: 0128 Train Loss= 0.056143768 Test loss= 0.056536306
# Epoch: 0129 Train Loss= 0.055325974 Test loss= 0.056110647
# Epoch: 0130 Train Loss= 0.056394149 Test loss= 0.057040691
# Epoch: 0131 Train Loss= 0.057196219 Test loss= 0.058083609
# Epoch: 0132 Train Loss= 0.056213103 Test loss= 0.056314435
# Epoch: 0133 Train Loss= 0.054138154 Test loss= 0.056099679
# Epoch: 0134 Train Loss= 0.054620482 Test loss= 0.055144884
# Epoch: 0135 Train Loss= 0.054757472 Test loss= 0.055338472
# Epoch: 0136 Train Loss= 0.054808974 Test loss= 0.054904845
# Epoch: 0137 Train Loss= 0.056215908 Test loss= 0.056330889
# Epoch: 0138 Train Loss= 0.055092901 Test loss= 0.054132111
# Epoch: 0139 Train Loss= 0.056988746 Test loss= 0.057415321
# Epoch: 0140 Train Loss= 0.052896310 Test loss= 0.053218778
# Epoch: 0141 Train Loss= 0.053767946 Test loss= 0.054366145
# Epoch: 0142 Train Loss= 0.055056509 Test loss= 0.053933397
# Epoch: 0143 Train Loss= 0.054055452 Test loss= 0.053386293
# Epoch: 0144 Train Loss= 0.052845068 Test loss= 0.053215787
# Epoch: 0145 Train Loss= 0.054867085 Test loss= 0.054184008
# Epoch: 0146 Train Loss= 0.054114539 Test loss= 0.053712118
# Epoch: 0147 Train Loss= 0.054667871 Test loss= 0.054627992
# Epoch: 0148 Train Loss= 0.054002237 Test loss= 0.054700870
# Epoch: 0149 Train Loss= 0.054303430 Test loss= 0.054556929
# Epoch: 0150 Train Loss= 0.054552581 Test loss= 0.053196490
# Epoch: 0151 Train Loss= 0.052820433 Test loss= 0.052980170
# Epoch: 0152 Train Loss= 0.052497242 Test loss= 0.050708704
# Epoch: 0153 Train Loss= 0.053022154 Test loss= 0.054957293
# Epoch: 0154 Train Loss= 0.051442675 Test loss= 0.053461503
# Epoch: 0155 Train Loss= 0.051592473 Test loss= 0.052424449
# Epoch: 0156 Train Loss= 0.051474020 Test loss= 0.050831139
# Epoch: 0157 Train Loss= 0.051912155 Test loss= 0.052048028
# Epoch: 0158 Train Loss= 0.050879274 Test loss= 0.050920472
# Epoch: 0159 Train Loss= 0.051027715 Test loss= 0.051343668
# Epoch: 0160 Train Loss= 0.048326988 Test loss= 0.049729571
# Epoch: 0161 Train Loss= 0.050343227 Test loss= 0.051368549
# Epoch: 0162 Train Loss= 0.050793268 Test loss= 0.049965370
# Epoch: 0163 Train Loss= 0.050960958 Test loss= 0.051847670
# Epoch: 0164 Train Loss= 0.050967548 Test loss= 0.050208896
# Epoch: 0165 Train Loss= 0.048459683 Test loss= 0.050961219
# Epoch: 0166 Train Loss= 0.050564300 Test loss= 0.051111829
# Epoch: 0167 Train Loss= 0.048808027 Test loss= 0.049545690
# Epoch: 0168 Train Loss= 0.050218631 Test loss= 0.052041691
# Epoch: 0169 Train Loss= 0.049438275 Test loss= 0.048881311
# Epoch: 0170 Train Loss= 0.049357388 Test loss= 0.051225901
# Epoch: 0171 Train Loss= 0.049657997 Test loss= 0.050095398
# Epoch: 0172 Train Loss= 0.048414610 Test loss= 0.048924722
# Epoch: 0173 Train Loss= 0.048975017 Test loss= 0.048982169
# Epoch: 0174 Train Loss= 0.050090801 Test loss= 0.049142763
# Epoch: 0175 Train Loss= 0.049087003 Test loss= 0.048519041
# Epoch: 0176 Train Loss= 0.048986252 Test loss= 0.048664063
# Epoch: 0177 Train Loss= 0.047591731 Test loss= 0.047989581
# Epoch: 0178 Train Loss= 0.048167050 Test loss= 0.048714288
# Epoch: 0179 Train Loss= 0.048224293 Test loss= 0.048376031
# Epoch: 0180 Train Loss= 0.046420068 Test loss= 0.048201308
# Epoch: 0181 Train Loss= 0.050606411 Test loss= 0.048057336
# Epoch: 0182 Train Loss= 0.048269842 Test loss= 0.047662724
# Epoch: 0183 Train Loss= 0.048665073 Test loss= 0.048717022
# Epoch: 0184 Train Loss= 0.047485683 Test loss= 0.047269519
# Epoch: 0185 Train Loss= 0.048822433 Test loss= 0.048710395
# Epoch: 0186 Train Loss= 0.048060112 Test loss= 0.047643136
# Epoch: 0187 Train Loss= 0.047975194 Test loss= 0.048157535
# Epoch: 0188 Train Loss= 0.048781853 Test loss= 0.049002573
# Epoch: 0189 Train Loss= 0.047153220 Test loss= 0.047666818
# Epoch: 0190 Train Loss= 0.049301587 Test loss= 0.049622394
# Epoch: 0191 Train Loss= 0.048183650 Test loss= 0.048693214
# Epoch: 0192 Train Loss= 0.046015613 Test loss= 0.046729323
# Epoch: 0193 Train Loss= 0.048637763 Test loss= 0.048814423
# Epoch: 0194 Train Loss= 0.047526315 Test loss= 0.047763456
# Epoch: 0195 Train Loss= 0.048484400 Test loss= 0.048611432
# Epoch: 0196 Train Loss= 0.046251491 Test loss= 0.046408579
# Epoch: 0197 Train Loss= 0.044274431 Test loss= 0.045781456
# Epoch: 0198 Train Loss= 0.045113463 Test loss= 0.045520622
# Epoch: 0199 Train Loss= 0.045650452 Test loss= 0.045524109
# Epoch: 0200 Train Loss= 0.045350153 Test loss= 0.046152063
# Done!

# %% [markdown]
# ### Results discution
#
# After training our model let's visualize the loss over the iterations

# %%
plt.figure(figsize=(10,5))
plt.plot(Learning_losses, label="Learning Loss", color='darkorange')
plt.plot(Test_losses, label="Testing Loss", color='blue')
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.title("Loss on Training Phase")
plt.legend()
plt.show()

# %% [markdown]
# Now lets compare results with the original data

# %%
f, a = plt.subplots(5, display, figsize=(display, 5))
for i in range(display):
    
    a[0][i].imshow(np.reshape(mnist.test.images[i], (28, 28)))
    a[1][i].imshow(np.reshape(mnist.test.images[i+10], (28, 28)))
    a[2][i].imshow(np.reshape(mnist.test.images[i+20], (28, 28)))
    a[3][i].imshow(np.reshape(mnist.test.images[i+30], (28, 28)))
    a[4][i].imshow(np.reshape(mnist.test.images[i+40], (28, 28)))
    f.show()
plt.title("Original data")
plt.draw()
plt.show()

# %%
f, a = plt.subplots(5, display, figsize=(display, 5))
for i in range(display):
    a[0][i].imshow(np.reshape(encode_decode_total[i], (28, 28)))
    a[1][i].imshow(np.reshape(encode_decode_total[i+10], (28, 28)))
    a[2][i].imshow(np.reshape(encode_decode_total[i+20], (28, 28)))
    a[3][i].imshow(np.reshape(encode_decode_total[i+30], (28, 28)))
    a[4][i].imshow(np.reshape(encode_decode[i+40], (28, 28)))
    f.show()
plt.draw()
plt.show()

# %% [markdown]
# ### Discution
# we can observe that the reconstructed data is highly accurate with the presence of some noise.
#
# ## Conclusion
#
# We can conclude that the introduction of the LLE combined with the DAE results on a very interesting non linear Dimentionality reduction with great results.
